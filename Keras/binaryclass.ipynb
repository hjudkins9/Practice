# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# 1. Generate a 2D binary classification dataset
X, y = make_classification(n_samples=500, n_features=2, n_informative=2, n_redundant=0, n_clusters_per_class=1, random_state=42)

# 2. Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Train-test split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# 4. Define a simple neural network model in keras
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(2,)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# 5. Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# 6. Train the model and capture training history
history = model.fit(X_train, y_train, epochs=30, batch_size=16, validation_split=0.2)

# 7. Plot the dataset
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=y, cmap='bwr', edgecolors='k', alpha=.7)
plt.title("2D binary Classification Dataset")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.grid(True)

# 8. Plot accuracy over epochs
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Aaccuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/30
# /usr/local/python/3.12.1/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4250 - loss: 0.7238 - val_accuracy: 0.4500 - val_loss: 0.7023
# Epoch 2/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4594 - loss: 0.7019 - val_accuracy: 0.5625 - val_loss: 0.6801
# Epoch 3/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5188 - loss: 0.6788 - val_accuracy: 0.6375 - val_loss: 0.6569
# Epoch 4/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5813 - loss: 0.6548 - val_accuracy: 0.7375 - val_loss: 0.6313
# Epoch 5/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7563 - loss: 0.6301 - val_accuracy: 0.8625 - val_loss: 0.6065
# Epoch 6/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8406 - loss: 0.6051 - val_accuracy: 0.8750 - val_loss: 0.5847
# Epoch 7/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8625 - loss: 0.5819 - val_accuracy: 0.9000 - val_loss: 0.5605
# Epoch 8/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8687 - loss: 0.5579 - val_accuracy: 0.9000 - val_loss: 0.5378
# Epoch 9/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8656 - loss: 0.5354 - val_accuracy: 0.9000 - val_loss: 0.5157
# Epoch 10/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8719 - loss: 0.5137 - val_accuracy: 0.8750 - val_loss: 0.4947
# Epoch 11/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8719 - loss: 0.4926 - val_accuracy: 0.8875 - val_loss: 0.4746
# Epoch 12/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8656 - loss: 0.4739 - val_accuracy: 0.8875 - val_loss: 0.4543
# Epoch 13/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8656 - loss: 0.4552 - val_accuracy: 0.8875 - val_loss: 0.4366
# Epoch 14/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8719 - loss: 0.4379 - val_accuracy: 0.9125 - val_loss: 0.4206
# Epoch 15/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8625 - loss: 0.4223 - val_accuracy: 0.9125 - val_loss: 0.4053
# Epoch 16/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8625 - loss: 0.4074 - val_accuracy: 0.9000 - val_loss: 0.3911
# Epoch 17/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8656 - loss: 0.3935 - val_accuracy: 0.8875 - val_loss: 0.3790
# Epoch 18/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8687 - loss: 0.3811 - val_accuracy: 0.8875 - val_loss: 0.3672
# Epoch 19/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8656 - loss: 0.3695 - val_accuracy: 0.8875 - val_loss: 0.3563
# Epoch 20/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8656 - loss: 0.3593 - val_accuracy: 0.8875 - val_loss: 0.3449
# Epoch 21/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8687 - loss: 0.3496 - val_accuracy: 0.9000 - val_loss: 0.3361
# Epoch 22/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8656 - loss: 0.3407 - val_accuracy: 0.8875 - val_loss: 0.3281
# Epoch 23/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8656 - loss: 0.3331 - val_accuracy: 0.9000 - val_loss: 0.3220
# Epoch 24/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8656 - loss: 0.3257 - val_accuracy: 0.9000 - val_loss: 0.3154
# Epoch 25/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8687 - loss: 0.3199 - val_accuracy: 0.9000 - val_loss: 0.3086
# Epoch 26/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8687 - loss: 0.3144 - val_accuracy: 0.9000 - val_loss: 0.3033
# Epoch 27/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8687 - loss: 0.3096 - val_accuracy: 0.9000 - val_loss: 0.2989
# Epoch 28/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8687 - loss: 0.3056 - val_accuracy: 0.9000 - val_loss: 0.2949
# Epoch 29/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8687 - loss: 0.3011 - val_accuracy: 0.9000 - val_loss: 0.2899
# Epoch 30/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8719 - loss: 0.2977 - val_accuracy: 0.9000 - val_loss: 0.2870
